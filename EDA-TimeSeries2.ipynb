# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime

# %%
df_tesla = pdr.get_data_yahoo('TSLA')

# %%
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-06-30   73.353996   71.924004   72.741997   72.321999  29242500.0
# 2017-07-03   74.269997   70.300003   74.047997   70.524002  31527000.0
# 2017-07-05   69.447998   65.265999   69.440002   65.417999  85233500.0
# 2017-07-06   64.157997   61.259998   63.452000   61.765999  96622500.0
# 2017-07-07   63.400002   61.476002   62.700001   62.644001  70884500.0
# ...                ...         ...         ...         ...         ...
# 2022-06-23  717.950012  685.909973  713.719971  705.210022  34734200.0
# 2022-06-24  738.200012  708.260010  712.409973  737.119995  31866500.0
# 2022-06-27  756.210022  727.700012  748.099976  734.760010  29726100.0
# 2022-06-28  749.909973  697.030029  733.450012  697.989990  30130400.0
# 2022-06-29  693.520020  666.820007  691.500000  685.469971  27578500.0
#
#              Adj Close
# Date
# 2017-06-30   72.321999
# 2017-07-03   70.524002
# 2017-07-05   65.417999
# 2017-07-06   61.765999
# 2017-07-07   62.644001
# ...                ...
# 2022-06-23  705.210022
# 2022-06-24  737.119995
# 2022-06-27  734.760010
# 2022-06-28  697.989990
# 2022-06-29  685.469971
#
# [1258 rows x 6 columns]

# %% [markdown]
# ###  Simple Moving Average

# %%
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open: 10 days rolling'] = df_tesla['Open'].rolling(window=10, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(window=30, min_periods=1).mean()
df_tesla['Open: 50 days rolling'] = df_tesla['Open'].rolling(window=50, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling','Open: 30 days rolling','Open: 50 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Cummulative moving average

# %%
## expanding

df_tesla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Exponential weighted moving average

# %%
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['EMA_0.3'] = df_tesla['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['EMA_5_days'] = df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','EMA_5_days']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla[['Open','EMA_0.1','EMA_5_days']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print(1)
# Out:
# 1
